# %% [markdown]
# # This notebook involved the implementation of `Tensorflow` and `Pytorch`  from scratch.

# %% [markdown]
# ## TensorFlow

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

# %%
class MyDenseLayer(tf.keras.layers.Layer):
    def __init__(self, input_dim, output_dim):
        super(MyDenseLayer, self).__init__()

        # initialize weights and biases
        self.W = self.add_weight(input_dim, output_dim)
        self.b = self.add_weight(1, output_dim)

    # Forward pass
    def call(self,inputs):
        
        z = tf.matmul(inputs, self.W) + self.b

        output = tf.math.sigmoid(z)
        return output

# %% [markdown]
# ## Pytorch

# %%
import numpy as np
import torch
import torch.nn as nn
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 2
#       1 import numpy as np
# ----> 2 import pytorch as torch
#       3 import torch.nn as nn
#
# ModuleNotFoundError: No module named 'pytorch'

# %%
class MyDenseLayer(nn.Module):

    def __init__(self, input_dim, output_dim):
        super(MyDenseLayer, self).__init__()

        # initialize the weights and biases
        self.w = nn.Parameter(torch.randn(input_dim, output_dim, requires_grad=True))
        self.b = nn.Parameter(torch.randn(1, output_dim, requires_grad=True))

    # Forward pass
    def forward(self, x):

        z = torch.matmul(x, self.w) + self.b

        output = torch.sigmoid(z)

        return output

# %% [markdown]
# ### Regarding the dense layer tensorflow and pytorch already have implement it so we don't need to write this class code everytime.

# %% [markdown]
# **Tensorflow**

# %%
import tensorflow as tf

layer = tf.keras.layers.Dense(units=2)

# %%
import torch.nn as nn 

layer = nn.Linear(in_features=3, out_features=2)
