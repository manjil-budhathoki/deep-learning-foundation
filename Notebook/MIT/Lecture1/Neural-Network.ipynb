# %% [markdown]
# # Single Layer Neural Network

# %% [markdown]
# ### Multi Oytput Perceptron

# %%
import tensorflow as tf
# Out:
# 2026-01-16 14:39:34.685401: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-01-16 14:39:34.753367: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-01-16 14:39:36.542407: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
model = tf.keras.Sequential(
    [
        tf.keras.layers.Dense(n),
        tf.keras.layers.Dense(2)
    ]
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 model = tf.keras.Sequential(
#       2     [
# ----> 3         tf.keras.layers.Dense(n),
#       4         tf.keras.layers.Dense(2)
#       5     ]
#       6 )
#
# NameError: name 'n' is not defined

# %%
from torch import nn

model = nn.Sequential(
    n.Linear(m,n),
    nn.ReLU(),
    nn.Linear(n,2)
)

# %% [markdown]
# # Deep Neural Network

# %%
model = tf.keras.Sequential([
    tf.keras.layer.Dense(n1),
    tf.keras.layer.Dense(n2),
    ...,
    tf.keras.layer.Dense(2)
])

# %%
# torch implementation adding more layers deep layer or we can say hidden layers
model = nn.Sequential(
    n.Linear(m,n1),
    nn.ReLU(),
    nn.Linear(n1,n2),
    nn.ReLU(),
    ...,
    nn.Linear(nK,2)
)
